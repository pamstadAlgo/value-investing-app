# %%
#try to extract price information from yahoo finance & quickfs; it is prefered to do it from yahoo finance as this will to contribute to the limited number of requests we have from quickfs
import yfinance as yf

# %%
tsat = yf.Ticker("ABEDSDEE")

# %%
tsat
# Out:
# yfinance.Ticker object <ABEDSDEE>

# %%
tsat.info
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/ABEDSDEE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=ABEDSDEE&crumb=PGJ4J8Taf7e
# {'trailingPegRatio': None}

# %%
# get all stock info
type(tsat.info)
# Out:
# dict

# %%
tsat.info
# Out:
# {'address1': '160 Elgin Street',
#  'address2': 'Suite 2100',
#  'city': 'Ottawa',
#  'state': 'ON',
#  'zip': 'K2P 2P7',
#  'country': 'Canada',
#  'phone': '613 748 0123',
#  'website': 'https://www.telesat.com',
#  'industry': 'Communication Equipment',
#  'industryKey': 'communication-equipment',
#  'industryDisp': 'Communication Equipment',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
tsat.info["impliedSharesOutstanding"]
# Out:
# 50268200

# %%
tsat.info["currentPrice"]
# Out:
# 9.6
