# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data_q1 = pd.read_csv("Data/USA/bulk_quarterly_financials_1.csv")
data_q2 = pd.read_csv("Data/USA/bulk_quarterly_financials_2.csv")
data_q3 = pd.read_csv("Data/USA/bulk_quarterly_financials_3.csv")
data_q4 = pd.read_csv("Data/USA/bulk_quarterly_financials_4.csv")
data_q5 = pd.read_csv("Data/USA/bulk_quarterly_financials_5.csv")

# %%
data_q1.head()
# Out:
#   symbol qfs_symbol exchange         name company_type currency  \
# 0   ANNX    ANNX:US   NASDAQ  Annexon Inc       normal      USD
# 1   ANNX    ANNX:US   NASDAQ  Annexon Inc       normal      USD
# 2   ANNX    ANNX:US   NASDAQ  Annexon Inc       normal      USD
# 3   ANNX    ANNX:US   NASDAQ  Annexon Inc       normal      USD
# 4   ANNX    ANNX:US   NASDAQ  Annexon Inc       normal      USD
#
#         industry period_type period_end_date  revenue  ...  \
# 0  Biotechnology          FQ         2021-09      0.0  ...
# 1  Biotechnology          FQ         2020-03      0.0  ...
# 2  Biotechnology          FQ         2019-12      0.0  ...
# 3  Biotechnology          FQ         2019-06      0.0  ...
# 4  Biotechnology          FQ         2019-03      0.0  ...
#
#    assets_to_equity_median  debt_to_assets_median  debt_to_equity_median  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# ...

# %%
data_q1[(data_q1['symbol'] == 'TIMGF') & (data_q1['period_end_date'] == '2019-01')]['period_end_price']
# Out:
# 14766    0.06
# Name: period_end_price, dtype: float64

# %%
data_q1[(data_q1['symbol'] == 'DCGD') & (data_q1['period_end_date'] == '2019-02')]
# Out:
# Empty DataFrame
# ...

# %%
annual_data = pd.read_csv('bulk_annual_financials_sample_small.csv')

# %%
def opex_csy_check(row):
    """
    Function which checks that the operating expenses data is consistent. We have different use cases for "normal" companies (everything except banks & insurances), banks & insurances
    
    normal use case:
        total opex = cogs + sga + rnd + special_charges + other_opex
    """
    if row['company_type'] == 'normal':
        print('we check a normal company')

# %%
annual_data.head()
# Out:
#   symbol qfs_symbol exchange       name company_type currency  \
# 0   AAPL    AAPL:US   NASDAQ  Apple Inc       normal      USD
# 1   AAPL    AAPL:US   NASDAQ  Apple Inc       normal      USD
# 2   AAPL    AAPL:US   NASDAQ  Apple Inc       normal      USD
# 3   AAPL    AAPL:US   NASDAQ  Apple Inc       normal      USD
# 4   AAPL    AAPL:US   NASDAQ  Apple Inc       normal      USD
#
#                                      industry period_type period_end_date  \
# 0  Technology Hardware, Storage & Peripherals          FY         2011-09
# 1  Technology Hardware, Storage & Peripherals          FY         2014-09
# 2  Technology Hardware, Storage & Peripherals          FY         2013-09
# 3  Technology Hardware, Storage & Peripherals          FY         2002-09
# 4  Technology Hardware, Storage & Peripherals          FY         2010-09
#
#         revenue  ...  assets_to_equity_median  debt_to_assets_median  \
# 0  1.082490e+11  ...                      NaN                    NaN
# ...
