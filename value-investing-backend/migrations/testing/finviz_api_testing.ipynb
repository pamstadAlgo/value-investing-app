# %%
from finvizfinance.screener.overview import Overview

# %%
foverview = Overview()

# %%
foverview.get_filters()
# Out:
# ['Exchange',
#  'Index',
#  'Sector',
#  'Industry',
#  'Country',
#  'Market Cap.',
#  'P/E',
#  'Forward P/E',
#  'PEG',
#  'P/S',
#  'P/B',
#  'Price/Cash',
#  'Price/Free Cash Flow',
#  'EPS growththis year',
#  'EPS growthnext year',
#  'EPS growthpast 5 years',
#  'EPS growthnext 5 years',
#  'Sales growthpast 5 years',
#  'EPS growthqtr over qtr',
#  'Sales growthqtr over qtr',
#  'Dividend Yield',
#  'Return on Assets',
#  'Return on Equity',
#  'Return on Investment',
#  'Current Ratio',
#  'Quick Ratio',
#  'LT Debt/Equity',
#  'Debt/Equity',
#  'Gross Margin',
#  'Operating Margin',
#  'Net Profit Margin',
#  'Payout Ratio',
#  'InsiderOwnership',
#  'InsiderTransactions',
#  'InstitutionalOwnership',
#  'InstitutionalTransactions',
#  'Float Short',
#  'Analyst Recom.',
#  'Option/Short',
#  'Earnings Date',
#  'Performance',
#  'Performance 2',
#  'Volatility',
#  'RSI (14)',
#  'Gap',
#  '20-Day Simple Moving Average',
#  '50-Day Simple Moving Average',
# ...

# %%
filter_dict ={'P/E': 'Under 10', 'EPS growthpast 5 years' : 'Over 10%', 'Return on Investment': 'Over +10%',  'Market Cap.' : 'Small ($300mln to $2bln)' }

# %%
foverview.set_filter(filters_dict=filter_dict)

# %%
df = foverview.screener_view()
# Out:
# [Info] loading page [##############################] 8/8

# %%
df.sort_values(by=['P/E'])
# Out:
#     Ticker\n\n                                   Company       Sector  \
# 153        ZIM     ZIM Integrated Shipping Services Ltd.  Industrials
# 105        OBE                      Obsidian Energy Ltd.       Energy
# 122        RTC                       Baijiayun Group Ltd   Technology
# 103        NMM             Navios Maritime Partners L.P.  Industrials
# 1         AMBC               Ambac Financial Group, Inc.    Financial
# ..         ...                                       ...          ...
# 27        CSTR          CapStar Financial Holdings, Inc.    Financial
# 49         FCF  First Commonwealth Financial Corporation    Financial
# 93        MCBS                MetroCity Bankshares, Inc.    Financial
# 6         BANC                  Banc of California, Inc.    Financial
# 37        DNOW                                  NOW Inc.       Energy
#
#                            Industry Country    Market Cap   P/E  Price  \
# ...

# %%
df.head()
# Out:
#   Ticker\n\n                       Company       Sector  \
# 0       AMAL   Amalgamated Financial Corp.    Financial
# 1       AMBC   Ambac Financial Group, Inc.    Financial
# 2       AMRK  A-Mark Precious Metals, Inc.    Financial
# 3       AROW   Arrow Financial Corporation    Financial
# 4        ASC  Ardmore Shipping Corporation  Industrials
#
#                 Industry  Country   Market Cap   P/E  Price  Change     Volume
# 0       Banks - Regional      USA  569990000.0  6.66   19.5  -0.023    96210.0
# 1  Insurance - Specialty      USA  655290000.0  1.32  14.05 -0.0064   178804.0
# 2        Capital Markets      USA  926950000.0  6.59  40.62 -0.0042   101158.0
# 3       Banks - Regional      USA  336020000.0  7.52  20.34  0.0109    30983.0
# 4        Marine Shipping  Bermuda  552480000.0  2.98  13.75 -0.0234  1244600.0

# %%
foverview.get_filter_options('Market Cap.')
# Out:
# ['Any',
#  'Mega ($200bln and more)',
#  'Large ($10bln to $200bln)',
#  'Mid ($2bln to $10bln)',
#  'Small ($300mln to $2bln)',
#  'Micro ($50mln to $300mln)',
#  'Nano (under $50mln)',
#  '+Large (over $10bln)',
#  '+Mid (over $2bln)',
#  '+Small (over $300mln)',
#  '+Micro (over $50mln)',
#  '-Large (under $200bln)',
#  '-Mid (under $10bln)',
#  '-Small (under $2bln)',
#  '-Micro (under $300mln)']

# %%
filters_dict = {'Exchange':'AMEX','Sector':'Basic Materials'}
foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view()
df.head()
# Out:
# [Info] loading page [##############################] 3/3
#   Ticker\n\n                         Company           Sector  \
# 0        AAU           Almaden Minerals Ltd.  Basic Materials
# 1        ASM  Avino Silver & Gold Mines Ltd.  Basic Materials
# 2       AUMN         Golden Minerals Company  Basic Materials
# 3       AUST               Austin Gold Corp.  Basic Materials
# 4        BTG                    B2Gold Corp.  Basic Materials
#
#                          Industry Country    Market Cap    P/E Price  Change  \
# 0                            Gold  Canada    19580000.0    NaN  0.15 -0.0434
# 1  Other Precious Metals & Mining  Canada    86740000.0  42.41  0.72 -0.0378
# 2  Other Precious Metals & Mining     USA     9750000.0    NaN  1.28 -0.0376
# 3                            Gold  Canada    11500000.0    NaN  0.88  0.0042
# 4                            Gold  Canada  4390000000.0  14.13  3.39 -0.0287
#
#       Volume
# 0   164245.0
# 1   416539.0
# 2    86237.0
# ...

# %%
endRevenue = 94836000000 + 117154000000 + 90146000000 + 82959000000
startRevenue = 97278000000 + 123945000000 + 83360000000 + 81434000000

# %%
endRevenue
# Out:
# 385095000000

# %%
startRevenue
# Out:
# 386017000000

# %%
cagrTTM = endRevenue/startRevenue -1

# %%
cagrTTM*100
# Out:
# -0.2388495843447358

# %%
2023-04-01
2022-06-25


2023-06-30
2022-09-30
