# %%
import sys
import os
import uuid
import django
import collections
#create django setup; needed otherwise we cannot use django models outside of django apps
sys.path.append("..")
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "valueinvesting.settings")
django.setup()

from quickfs_dj.models import KeyRatiosQuarter, IncomeStatementAnnual, TradedCompanies, IncomeStatementQuarter, BalanceSheetQuarter, BalanceSheetAnnual

# %%
TICKER = 'TSLA'

# %%
tsla_balance_sheet = BalanceSheetAnnual.objects.filter(ticker_id = TICKER).order_by('period_end_date')

# %%
for row in tsla_balance_sheet:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# SynchronousOnlyOperation                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 for row in tsla_balance_sheet:
#       2     print(row)
#
# File ~/.virtualenvs/dcf/lib/python3.9/site-packages/django/db/models/query.py:398, in QuerySet.__iter__(self)
#     383 def __iter__(self):
#     384     """
#     385     The queryset iterator protocol uses three nested iterators in the
#     386     default case:
#    (...)
#     396            - Responsible for turning the rows into model objects.
#     397     """
# --> 398     self._fetch_all()
#     399     return iter(self._result_cache)
#
# File ~/.virtualenvs/dcf/lib/python3.9/site-packages/django/db/models/query.py:1881, in QuerySet._fetch_all(self)
#    1879 def _fetch_all(self):
#    1880     if self._result_cache is None:
# -> 1881         self._result_cache = list(self._iterable_class(self))
# ...
