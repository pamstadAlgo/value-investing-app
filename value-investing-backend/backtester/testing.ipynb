# %%
from django.conf import settings
settings.configure(
    DATABASE_ENGINE = 'postgresql_psycopg2',
    DATABASE_NAME = 'value-investing-dev',
    DATABASE_USER = 'postgres',
    DATABASE_PASSWORD = 'v,1846PSVv,1846PSV',
    DATABASE_HOST = 'localhost',
    DATABASE_PORT = '5432',
)

# %%
from ..valueinvesting.quickfs.models import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/pa/Desktop/SideProjects/Valuation/value-investing-app/value-investing-backend/Backtester/testing.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/pa/Desktop/SideProjects/Valuation/value-investing-app/value-investing-backend/Backtester/testing.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from ..valueinvesting.quickfs.models import *
#
# ImportError: attempted relative import with no known parent package
